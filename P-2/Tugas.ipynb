# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

data = 'wbc.csv' # path dataset
df = pd.read_csv(data) # load dataset

# %%
df.head() # show the first 5 rows
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# NO 1

df = df.iloc[:, 1:-1]
df.head(50)
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          M       17.990         10.38          122.80     1001.0
# 1          M       20.570         17.77          132.90     1326.0
# 2          M       19.690         21.25          130.00     1203.0
# 3          M       11.420         20.38           77.58      386.1
# 4          M       20.290         14.34          135.10     1297.0
# 5          M       12.450         15.70           82.57      477.1
# 6          M       18.250         19.98          119.60     1040.0
# 7          M       13.710         20.83           90.20      577.9
# 8          M       13.000         21.82           87.50      519.8
# 9          M       12.460         24.04           83.97      475.9
# 10         M       16.020         23.24          102.70      797.8
# 11         M       15.780         17.89          103.60      781.0
# 12         M       19.170         24.80          132.40     1123.0
# ...

# %%
# No 2

le = LabelEncoder() # membuat objek dari LabelEncoder
df['diagnosis'] = le.fit_transform(df['diagnosis']) # proses encoding

# %%
df.head(50)
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           1       17.990         10.38          122.80     1001.0
# 1           1       20.570         17.77          132.90     1326.0
# 2           1       19.690         21.25          130.00     1203.0
# 3           1       11.420         20.38           77.58      386.1
# 4           1       20.290         14.34          135.10     1297.0
# 5           1       12.450         15.70           82.57      477.1
# 6           1       18.250         19.98          119.60     1040.0
# 7           1       13.710         20.83           90.20      577.9
# 8           1       13.000         21.82           87.50      519.8
# 9           1       12.460         24.04           83.97      475.9
# 10          1       16.020         23.24          102.70      797.8
# 11          1       15.780         17.89          103.60      781.0
# 12          1       19.170         24.80          132.40     1123.0
# ...

# %%
# NO 3

numeric_cols = df.columns[1:] # mengambil kolom numerik

scaler = StandardScaler() # membuat objek dari StandardScaler

df[numeric_cols] = scaler.fit_transform(df[numeric_cols]) # proses standardisasi
df.head(50)
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           1     1.097064     -2.073335        1.269934   0.984375
# 1           1     1.829821     -0.353632        1.685955   1.908708
# 2           1     1.579888      0.456187        1.566503   1.558884
# 3           1    -0.768909      0.253732       -0.592687  -0.764464
# 4           1     1.750297     -1.151816        1.776573   1.826229
# 5           1    -0.476375     -0.835335       -0.387148  -0.505650
# 6           1     1.170908      0.160649        1.138125   1.095295
# 7           1    -0.118517      0.358450       -0.072867  -0.218965
# 8           1    -0.320167      0.588830       -0.184080  -0.384207
# 9           1    -0.473535      1.105439       -0.329482  -0.509063
# 10          1     0.537556      0.919273        0.442011   0.406453
# 11          1     0.469393     -0.325708        0.479082   0.358672
# 12          1     1.432201      1.282296        1.665360   1.331355
# ...

# %%
# No 4

import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df_train, df_test = train_test_split(df, test_size=0.2, random_state=0)
print(f'Jumlah data asli: {df.shape[0]}')
print(f'Jumlah data train: {df_train.shape[0]}')
print(f'Jumlah data test: {df_test.shape[0]}')

# Cek rasio tiap label
print('=========')
print(f'Jumlah label data asli:\n{df.diagnosis.value_counts()}')
print(f'Jumlah label data latih:\n{df_train.diagnosis.value_counts()}')
print(f'Jumlah label data Uji:\n{df_test.diagnosis.value_counts()}')
# Out:
# Jumlah data asli: 569
# Jumlah data train: 455
# Jumlah data test: 114
# ...
# Jumlah label data asli:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64
# Jumlah label data latih:
# diagnosis
# 0    290
# 1    165
# Name: count, dtype: int64
# Jumlah label data Uji:
# diagnosis
# 0    67
# 1    47
# Name: count, dtype: int64

# %%
# No 4 Cara yang lain

# Tentukan fitur dan label
X = df.drop(columns=['diagnosis'])  # Fitur
y = df['diagnosis']  # Label/Kelas

# Lakukan stratified split dengan rasio 80:20
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# Tampilkan jumlah data latih dan uji
print("Total Data Latih:", len(X_train))
print("Total Data Uji:", len(X_test))

# Total data latih dan uji
print("Total Data Latih:", len(X_train) + len(X_test))
# Out:
# Total Data Latih: 455
# Total Data Uji: 114
# Total Data Latih: 569
